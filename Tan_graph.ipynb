# %%
import math
import matplotlib.pyplot as plt

# %%
lst = []
plt.figure(figsize=[14, 8])
for i in range(720):
    lst.append(math.tan(math.pi/180*i))
plt.xlim(0,720)
plt.ylim(-30, 30)
plt.plot(lst)
